# %% [markdown]
# <a href="https://colab.research.google.com/github/vamsi160505-design/MLDA/blob/main/cross_validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Print CV scores
print("Decision Tree CV Scores per fold:", scores1)
print("Logistic Regression CV Scores per fold:", scores2)

# Visualize CV score distributions
cv_scores = {
    'Decision Tree': scores1,
    'Logistic Regression': scores2
}

# Convert to DataFrame for easy plotting
cv_df = pd.DataFrame(cv_scores)

plt.figure(figsize=(8,6))
sns.boxplot(data=cv_df)
plt.title("Cross-Validation Score Distribution per Model")
plt.ylabel("Accuracy")
plt.show()
# Out:
# Decision Tree CV Scores per fold: [0.92982456 0.96491228 0.9122807  0.89473684 0.92982456 0.85964912
#  0.96491228 0.98245614 0.94736842 0.96428571]
# Logistic Regression CV Scores per fold: [0.98245614 0.98245614 0.98245614 0.98245614 0.98245614 0.92982456
#  1.         0.98245614 0.94736842 0.98214286]
